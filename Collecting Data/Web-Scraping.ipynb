# %% [markdown]
# # **Web Scraping**

# %% [markdown]
# ## Extract information from the given web site

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# Import the required libraries

# %%
# Your code here
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Download the webpage at the url

# %%
#your code goes here
data = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
#your code goes here
soup = BeautifulSoup(data,'html.parser')

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
#your code goes here
table = soup.find('table')
for row in table.find_all('tr'):
    col = row.find_all('td')
    language = col[1].getText()
    salary = col[3].getText()
    print("{}--->{}".format(language,salary))
# Out:
# Language--->Average Annual Salary
# Python--->$114,383
# Java--->$101,013
# R--->$92,037
# Javascript--->$110,981
# Swift--->$130,801
# C++--->$113,865
# C#--->$88,726
# PHP--->$84,727
# SQL--->$84,793
# Go--->$94,082

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
# your code goes here
import pandas as pd
import numpy as np
language = []
salary = []
for row in soup.find("tbody").find_all("tr"):
  col = row.find_all("td")
  language.append(col[1].getText())
  salary.append(col[3].getText())

df = pd.DataFrame({'Language Name':language, 'Average Annual Salary':salary})
df.drop(index=df.index[0], axis=0, inplace=True)

print(df)

df.to_csv('popular-languages.csv')
# Out:
#    Language Name Average Annual Salary
# 1         Python              $114,383
# 2           Java              $101,013
# 3              R               $92,037
# 4     Javascript              $110,981
# 5          Swift              $130,801
# 6            C++              $113,865
# 7             C#               $88,726
# 8            PHP               $84,727
# 9            SQL               $84,793
# 10            Go               $94,082
